# %%
# Import required libraries and dependencies
import pandas as pd
import os
import warnings
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt


warnings.filterwarnings('ignore', message="KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.")

os.environ['OMP_NUM_THREADS'] = '1'

# %%
# Load the data into a Pandas DataFrame and make the index the "coin_id" column.
market_data_df = pd.read_csv("Resources/crypto_market_data.csv", index_col="coin_id")

# Display sample data
market_data_df.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
market_data_df.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
scaler = StandardScaler()

# Fit the scaler to the data
scaler.fit(market_data_df)

# Transform the data
scaled_data = scaler.transform(market_data_df)

#Display the scaled data
scaled_data[:5]
# Out:
# array([[ 0.50852937,  0.49319307,  0.77220043,  0.23545963, -0.0674951 ,
#         -0.35595348, -0.25163688],
#        [ 0.18544589,  0.93444504,  0.55869212, -0.05434093, -0.27348273,
#         -0.11575947, -0.19935211],
#        [ 0.02177396, -0.70633685, -0.02168042, -0.06103015,  0.00800452,
#         -0.55024692, -0.28206051],
#        [-0.04076438, -0.81092807,  0.24945797, -0.05038797, -0.37316402,
#         -0.45825882, -0.29554614],
#        [ 1.19303608,  2.00095907,  1.76061001,  0.54584206, -0.29120287,
#         -0.49984776, -0.27031695]])

# %%
# Create a DataFrame with the scaled data
scaled_df = pd.DataFrame(scaled_data, columns=market_data_df.columns, index=market_data_df.index)


# Copy the crypto names from the original data


# Set the coinid column as index



# Display sample data
scaled_df.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                             0.508529                    0.493193
# ethereum                            0.185446                    0.934445
# tether                              0.021774                   -0.706337
# ripple                             -0.040764                   -0.810928
# bitcoin-cash                        1.193036                    2.000959
# binancecoin                         0.891871                    1.327295
# chainlink                           0.011397                    2.572251
# cardano                             0.102530                    1.508001
# litecoin                            0.077497                    0.334297
# bitcoin-cash-sv                     0.448952                   -0.190684
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %% [markdown]
# ### Find the Best Value for k Using the Original Scaled DataFrame.

# %%
# Create a list with the number of k-values to try
# Use a range from 1 to 11
k_values = range(1, 11)


# Create an empty list to store the inertia values
inertia = []


# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using the scaled DataFrame
# 3. Append the model.inertia_ to the inertia list
for k in k_values:
    model = KMeans(n_clusters=k, random_state=0, n_init=10, max_iter=300, tol=1e-04)
    model.fit(scaled_df)
    inertia.append(model.inertia_)



# Create a dictionary with the data to plot the Elbow curve
elbow_data = {"k": k_values, "inertia": inertia}


# Create a DataFrame with the data to plot the Elbow curve
elbow_df = pd.DataFrame(elbow_data)


# Display the DataFrame
elbow_df.head(10)
# Out:
#     k     inertia
# 0   1  287.000000
# 1   2  198.571818
# 2   3  123.190482
# 3   4   79.022435
# 4   5   65.302379
# 5   6   52.101806
# 6   7   46.035250
# 7   8   37.284807
# 8   9   32.161417
# 9  10   28.075253

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
elbow_df.plot.line(x="k", y="inertia", title="Elbow Curve", xticks=k_values, xlabel="Number of clusters", ylabel="Inertia")
# Out:
# <Axes: title={'center': 'Elbow Curve'}, xlabel='Number of clusters', ylabel='Inertia'>

# %% [markdown]
# #### Answer the following question:
# **Question:** What is the best value for `k`?
#
# **Answer: 4 is the best k value**

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Scaled Data.

# %%
# Initialize the K-Means model using the best value for k
model = KMeans(n_clusters=4, random_state=0, n_init=10, max_iter=300, tol=1e-04)

# %%
# Fit the K-Means model using the scaled data
model.fit(scaled_df)
# Out:
# KMeans(n_clusters=4, n_init=10, random_state=0)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled data
clusters = model.predict(scaled_df)


# View the resulting array of cluster values.
clusters[:10]
# Out:
# array([2, 2, 0, 0, 2, 2, 2, 2, 2, 0])

# %%
# Create a copy of the DataFrame
clustered_df = scaled_df.copy()

# %%
# Add a new column to the DataFrame with the predicted clusters
clustered_df["predicted_cluster"] = model.labels_


# Display sample data
clustered_df.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                             0.508529                    0.493193
# ethereum                            0.185446                    0.934445
# tether                              0.021774                   -0.706337
# ripple                             -0.040764                   -0.810928
# bitcoin-cash                        1.193036                    2.000959
# binancecoin                         0.891871                    1.327295
# chainlink                           0.011397                    2.572251
# cardano                             0.102530                    1.508001
# litecoin                            0.077497                    0.334297
# bitcoin-cash-sv                     0.448952                   -0.190684
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Create a scatter plot using Pandas plot by setting 
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`.
# Use "rainbow" for the color to better visualize the data.
clustered_df.plot.scatter(x="price_change_percentage_24h", y="price_change_percentage_7d", c="predicted_cluster", colormap="rainbow", title="Clusters by Price Change", xlabel="Price Change 24h", ylabel="Price Change 7d")
# Out:
# <Axes: title={'center': 'Clusters by Price Change'}, xlabel='Price Change 24h', ylabel='Price Change 7d'>

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pca = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` on the original scaled DataFrame to reduce to three principal components.
crypto_pca = pca.fit_transform(scaled_df)


# View the first five rows of the DataFrame. 
crypto_pca[:5]
# Out:
# array([[-0.60066733,  0.84276006,  0.46159457],
#        [-0.45826071,  0.45846566,  0.95287678],
#        [-0.43306981, -0.16812638, -0.64175193],
#        [-0.47183495, -0.22266008, -0.47905316],
#        [-1.15779997,  2.04120919,  1.85971527]])

# %%
# Retrieve the explained variance to determine how much information  can be attributed to each principal component.
explained_variance = pca.explained_variance_ratio_

explained_variance
# Out:
# array([0.3719856 , 0.34700813, 0.17603793])

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer: The total explained variance is 0.89503166. Thus 89.5% of the variance can be attributed to the three components.**

# %%
# Create a new DataFrame with the PCA data.
# Note: The code for this step is provided for you

# Creating a DataFrame with the PCA data
pca_df = pd.DataFrame(
    data=crypto_pca, columns=["principal_component_1", "principal_component_2", "principal_component_3"], index=market_data_df.index
)


# Copy the crypto names from the original data


# Set the coinid column as index


# Display sample data
pca_df.head(10)
# Out:
#                  principal_component_1  principal_component_2  \
# coin_id
# bitcoin                      -0.600667               0.842760
# ethereum                     -0.458261               0.458466
# tether                       -0.433070              -0.168126
# ripple                       -0.471835              -0.222660
# bitcoin-cash                 -1.157800               2.041209
# binancecoin                  -0.516534               1.388377
# chainlink                    -0.450711               0.517699
# cardano                      -0.345600               0.729439
# litecoin                     -0.649468               0.432165
# bitcoin-cash-sv              -0.759014              -0.201200
#
#                  principal_component_3
# coin_id
# bitcoin                       0.461595
# ethereum                      0.952877
# tether                       -0.641752
# ripple                       -0.479053
# bitcoin-cash                  1.859715
# ...

# %% [markdown]
# ### Find the Best Value for k Using the PCA Data

# %%
# Create a list with the number of k-values to try
# Use a range from 1 to 11
k_values = range(1, 11)


# Create an empty list to store the inertia values
inertia = []


# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using PCA DataFrame.
# 3. Append the model.inertia_ to the inertia list
for k in k_values:
    model = KMeans(n_clusters=k, random_state=0, n_init=10, max_iter=300, tol=1e-04)
    model.fit(pca_df)
    inertia.append(model.inertia_)


# Create a dictionary with the data to plot the Elbow curve
pca_elbow_data = {"k": k_values, "inertia": inertia}


# Create a DataFrame with the data to plot the Elbow curve
pca_elbow_df = pd.DataFrame(pca_elbow_data)


# Display the DataFrame
pca_elbow_df.head(10)
# Out:
#     k     inertia
# 0   1  256.874086
# 1   2  168.811896
# 2   3   93.774626
# 3   4   49.665497
# 4   5   37.839466
# 5   6   27.720626
# 6   7   21.182776
# 7   8   17.016962
# 8   9   13.668325
# 9  10   10.484890

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
pca_elbow_df.plot.line(x="k", y="inertia", title="Elbow Curve", xticks=k_values, xlabel="Number of clusters", ylabel="Inertia")
# Out:
# <Axes: title={'center': 'Elbow Curve'}, xlabel='Number of clusters', ylabel='Inertia'>

# %% [markdown]
# #### Answer the following questions:
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:4 is the best k value.**
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:It does not differ from the original data.**

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the PCA Data

# %%
# Initialize the K-Means model using the best value for k
pca_model = KMeans(n_clusters=4, random_state=0, n_init=10, max_iter=300, tol=1e-04)

# %%
# Fit the K-Means model using the PCA data
pca_model.fit(pca_df)
# Out:
# KMeans(n_clusters=4, n_init=10, random_state=0)

# %%
# Predict the clusters to group the cryptocurrencies using the PCA data
pca_clusters = pca_model.predict(pca_df)


# Print the resulting array of cluster values.
pca_clusters[:10]
# Out:
# array([2, 2, 0, 0, 2, 2, 2, 2, 2, 0])

# %%
# Create a copy of the DataFrame with the PCA data
pca_clustered_df = pca_df.copy()


# Add a new column to the DataFrame with the predicted clusters
pca_clustered_df["predicted_cluster"] = pca_model.labels_


# Display sample data
pca_clustered_df.head(10)

#print(pca_clustered_df.columns)
# Out:
#                  principal_component_1  principal_component_2  \
# coin_id
# bitcoin                      -0.600667               0.842760
# ethereum                     -0.458261               0.458466
# tether                       -0.433070              -0.168126
# ripple                       -0.471835              -0.222660
# bitcoin-cash                 -1.157800               2.041209
# binancecoin                  -0.516534               1.388377
# chainlink                    -0.450711               0.517699
# cardano                      -0.345600               0.729439
# litecoin                     -0.649468               0.432165
# bitcoin-cash-sv              -0.759014              -0.201200
#
#                  principal_component_3  predicted_cluster
# coin_id
# bitcoin                       0.461595                  2
# ethereum                      0.952877                  2
# tether                       -0.641752                  0
# ...

# %%
# Create a scatter plot using hvPlot by setting `x="PCA1"` and `y="PCA2"`. 
# Use "predicted_cluster" for the color to better visualize the data.
plt.scatter(pca_clustered_df["principal_component_1"], pca_clustered_df["principal_component_2"], c=pca_clustered_df["predicted_cluster"], cmap="rainbow")
plt.title("Clusters by PCA")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.show()

# %% [markdown]
# ### Determine the Weights of Each Feature on each Principal Component

# %%
# Use the columns from the original scaled DataFrame as the index.
pca_component_weights = pd.DataFrame(pca.components_, columns=[scaled_df.columns], index=["principal_component_1", "principal_component_2", "principal_component_3"])

#Create a transposed DataFrame
pca_component_weights = pca_component_weights.T

# Display sample data
pca_component_weights.head(10)
# Out:
#                               principal_component_1  principal_component_2  \
# price_change_percentage_24h               -0.416728               0.358162
# price_change_percentage_7d                -0.102432               0.227432
# price_change_percentage_14d               -0.009162               0.540415
# price_change_percentage_30d                0.191523               0.562182
# price_change_percentage_60d                0.320365               0.434040
# price_change_percentage_200d               0.594468               0.027735
# price_change_percentage_1y                 0.568379              -0.150789
#
#                               principal_component_3
# price_change_percentage_24h               -0.218795
# price_change_percentage_7d                 0.787670
# price_change_percentage_14d                0.349534
# price_change_percentage_30d               -0.181744
# price_change_percentage_60d               -0.361377
# price_change_percentage_200d               0.039733
# ...

# %% [markdown]
# #### Answer the following question:
#
# * **Question:** Which features have the strongest positive or negative influence on each component?
#
# * **Answer:
#
# For Principal Component 1 the strongest positive influences are price_change_percentage_200d (0.594468) and price_change_percentage_1y (0.568379). The strongest negative influence is price_change_percentage_24h (-0.416728).
#
# For Principal Component 2 the strongest influences are price_change_percentage_30d (0.562182), price_change_percentage_14d (0.540415) and price_change_percentage_60d (0.434040).
#
# For Principal Component 3 the strongest positive influences are price_change_percentage_7d (0.787670) and price_change_percentage_14d
# (0.349534). The strongest negative influence is price_change_percentage_60d (-0.361377). **
